# %% [markdown]
# # LGMVIP -Data Science Task-1

# %%
# import the numpy and pandas
import pandas as pd
import numpy as np

# %%
#load the dataset 
df = pd.read_csv('/content/Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.drop('Id',axis=1,inplace=True) #drop Id columns from the iris Dataset

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.bar(df['Species'],df['SepalLengthCm'],width=0.5)
plt.title("Sepal Length vs Species")
plt.show()

# %%
plt.bar(df['Species'],df['SepalWidthCm'],width=0.5,color='orange')
plt.title("Sepal Width vs Species")
plt.show()

# %%
plt.bar(df['Species'],df['PetalLengthCm'],width=0.5,color='lightgreen')
plt.title("Petal Length vs Species")
plt.show()

# %%
plt.bar(df['Species'],df['PetalWidthCm'],width=0.5,color='green')
plt.title("Petal Width vs Species")
plt.show()

# %%
sns.pairplot(df,hue="Species")

# %%
# create a scatter plot of sepal length vs. width
plt.scatter(df.SepalLengthCm,df.SepalWidthCm)
plt.xlabel('Sepal length (cm)')
plt.ylabel('Sepal width (cm)')
plt.title('Iris dataset: sepal length vs. width')
plt.show()

# %%
sns.scatterplot(x="SepalLengthCm", y="SepalWidthCm", hue="Species", data=df)
plt.xlabel('Sepal length (cm)')
plt.ylabel('Sepal width (cm)')
plt.title('Scatter plot of Sepal length vs. Sepal width')
plt.show()

# %%
sns.scatterplot(x="PetalLengthCm", y="PetalWidthCm", hue="Species", data=df)
plt.xlabel('Petal length (cm)')
plt.ylabel('Petal width (cm)')
plt.title('Scatter plot of petal length vs. petal width')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(16,5))
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=df,hue='Species',ax=ax1)
sns.scatterplot(x='SepalWidthCm',y='PetalWidthCm',data=df,hue='Species',ax=ax2)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalWidthCm'>

# %%
sns.violinplot(x="Species", y="PetalLengthCm", data=df)
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.title('Violin plot of petalLength by species')
plt.show()

# %%
sns.violinplot(x="Species", y="SepalLengthCm", data=df)
plt.xlabel('Species')
plt.ylabel('Sepal width (cm)')
plt.title('Violin plot of Sepal Length by species')
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
X=df.drop(['Species'],axis=1)
y=df['Species']

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## *Logistic Regression*

# %%
from sklearn.linear_model import LogisticRegression

# %%
lrmodel =LogisticRegression()

# %%
lrmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predlr= lrmodel.predict(X_test)

# %%
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_predlr))
# Out:
# ACCURACY OF THE MODEL:  1.0

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
confusion_matrix(y_test,y_predlr)
# Out:
# array([[19,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  0, 16]])

# %%
print(classification_report(y_test, y_predlr))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        50
#       macro avg       1.00      1.00      1.00        50
#    weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

# %%
svcmodel = SVC()

# %%
svcmodel.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_predsvc=svcmodel.predict(X_test)

# %%
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_predsvc))
# Out:
# ACCURACY OF THE MODEL:  1.0

# %%
confusion_matrix(y_test,y_predsvc)
# Out:
# array([[19,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  0, 16]])

# %%
print(classification_report(y_test, y_predsvc))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        50
#       macro avg       1.00      1.00      1.00        50
#    weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model= RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn import metrics

# %%
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.98

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[19,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  1, 15]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       0.94      1.00      0.97        15
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.98        50
#       macro avg       0.98      0.98      0.98        50
#    weighted avg       0.98      0.98      0.98        50
